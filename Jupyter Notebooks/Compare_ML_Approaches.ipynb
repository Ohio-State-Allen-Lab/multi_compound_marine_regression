# %%
#Data Processing and Management
import os
import glob
import csv
import pandas as pd
import numpy as np
import math

#Imaging and Plotting
import matplotlib.pyplot as plt

# %%
path = r'PATH'

Lab_Glucose =pd.read_csv(path + '\\'+'Lab_Glucose.csv')
Lab_Glycine =pd.read_csv(path + '//'+'Lab_Glycine.csv')
Lab_Butyric_Acid =pd.read_csv(path + '//'+'Lab_Butyric_Acid.csv')

Field_Glucose =pd.read_csv(path + '//'+'Field_Glucose.csv')
Field_Glycine =pd.read_csv(path + '//'+'Field_Glycine.csv')
Field_Butyric_Acid =pd.read_csv(path + '//'+'Field_Butyric_Acid.csv')

Errors =pd.read_csv(path + '//'+'Errors.csv')

# %% [markdown]
# # Glucose

# %%
plt.scatter(Lab_Glucose['TRUE'], Lab_Glucose['GBR']-Lab_Glucose['TRUE'], color = 'crimson', label = 'GBR', marker='o')
plt.scatter(Lab_Glucose['TRUE'], Lab_Glucose['RF']-Lab_Glucose['TRUE'], color = 'darkorange', label = 'RF', marker='o')
plt.scatter(Lab_Glucose['TRUE'], Lab_Glucose['HGBR']-Lab_Glucose['TRUE'], color = 'gold', label = 'HGBR', marker='o')
plt.scatter(Lab_Glucose['TRUE'], Lab_Glucose['DT']-Lab_Glucose['TRUE'], color = 'darkgreen', label = 'DT', marker='o')
plt.scatter(Lab_Glucose['TRUE'], Lab_Glucose['KNN']-Lab_Glucose['TRUE'], color = 'dodgerblue', label = 'KNN', marker='o')
plt.scatter(Lab_Glucose['TRUE'], Lab_Glucose['SVR']-Lab_Glucose['TRUE'], color = 'darkorchid', label = 'SVR', marker='o')
plt.scatter(Lab_Glucose['TRUE'], Lab_Glucose['MLP']-Lab_Glucose['TRUE'], color = 'hotpink', label = 'MLP', marker='o')
plt.scatter(Lab_Glucose['TRUE'], Lab_Glucose['MLR']-Lab_Glucose['TRUE'], color = 'dimgray', label = 'MLR', marker='o')


plt.title('Spiked Lab Models')
plt.ylabel('Predicted - True Concentration (mM)')
plt.xlabel('True Concentration (mM)')

plt.legend(frameon = True, loc="upper right", ncol = 2)
plt.ylim(-50,50)
plt.axhline(0, color = 'grey', linewidth = 0.5)
plt.axhline((Lab_Glucose['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')
plt.axhline(-(Lab_Glucose['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')

# %%
plt.scatter(Field_Glucose['TRUE'], Field_Glucose['GBR']-Field_Glucose['TRUE'], color = 'crimson', label = 'GBR', marker='^')
plt.scatter(Field_Glucose['TRUE'], Field_Glucose['RF']-Field_Glucose['TRUE'], color = 'darkorange', label = 'RF', marker='^')
plt.scatter(Field_Glucose['TRUE'], Field_Glucose['HGBR']-Field_Glucose['TRUE'], color = 'gold', label = 'HGBR', marker='^')
plt.scatter(Field_Glucose['TRUE'], Field_Glucose['DT']-Field_Glucose['TRUE'], color = 'darkgreen', label = 'DT', marker='^')
plt.scatter(Field_Glucose['TRUE'], Field_Glucose['KNN']-Field_Glucose['TRUE'], color = 'dodgerblue', label = 'KNN', marker='^')
plt.scatter(Field_Glucose['TRUE'], Field_Glucose['SVR']-Field_Glucose['TRUE'], color = 'darkorchid', label = 'SVR', marker='^')
plt.scatter(Field_Glucose['TRUE'], Field_Glucose['MLP']-Field_Glucose['TRUE'], color = 'hotpink', label = 'MLP', marker='^')
plt.scatter(Field_Glucose['TRUE'], Field_Glucose['MLR']-Field_Glucose['TRUE'], color = 'dimgray', label = 'MLR', marker='^')


plt.title('Spiked Ocean Models')
#plt.ylabel('Predicted - True Concentration (mM)')
plt.xlabel('True Concentration (mM)')

#plt.legend(frameon = True, loc="upper right", ncol = 2)
plt.ylim(-50,50)
plt.axhline(0, color = 'grey', linewidth = 0.5)
plt.axhline((Field_Glucose['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')
plt.axhline(-(Field_Glucose['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')

# %% [markdown]
# # Glycine

# %%
plt.scatter(Lab_Glycine['TRUE'], Lab_Glycine['GBR']-Lab_Glycine['TRUE'], color = 'crimson', label = 'GBR', marker='o')
plt.scatter(Lab_Glycine['TRUE'], Lab_Glycine['RF']-Lab_Glycine['TRUE'], color = 'darkorange', label = 'RF', marker='o')
plt.scatter(Lab_Glycine['TRUE'], Lab_Glycine['HGBR']-Lab_Glycine['TRUE'], color = 'gold', label = 'HGBR', marker='o')
plt.scatter(Lab_Glycine['TRUE'], Lab_Glycine['DT']-Lab_Glycine['TRUE'], color = 'darkgreen', label = 'DT', marker='o')
plt.scatter(Lab_Glycine['TRUE'], Lab_Glycine['KNN']-Lab_Glycine['TRUE'], color = 'dodgerblue', label = 'KNN', marker='o')
plt.scatter(Lab_Glycine['TRUE'], Lab_Glycine['SVR']-Lab_Glycine['TRUE'], color = 'darkorchid', label = 'SVR', marker='o')
plt.scatter(Lab_Glycine['TRUE'], Lab_Glycine['MLP']-Lab_Glycine['TRUE'], color = 'hotpink', label = 'MLP', marker='o')
plt.scatter(Lab_Glycine['TRUE'], Lab_Glycine['MLR']-Lab_Glycine['TRUE'], color = 'dimgray', label = 'MLR', marker='o')


plt.title('Spiked Lab Models')
plt.ylabel('Predicted - True Concentration (mM)')
plt.xlabel('True Concentration (mM)')

plt.legend(frameon = True, loc="upper right", ncol = 2)
plt.ylim(-50,50)
plt.axhline(0, color = 'grey', linewidth = 0.5)
plt.axhline((Lab_Glycine['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')
plt.axhline(-(Lab_Glycine['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')

# %%
plt.scatter(Field_Glycine['TRUE'], Field_Glycine['GBR']-Field_Glycine['TRUE'], color = 'crimson', label = 'GBR', marker='^')
plt.scatter(Field_Glycine['TRUE'], Field_Glycine['RF']-Field_Glycine['TRUE'], color = 'darkorange', label = 'RF', marker='^')
plt.scatter(Field_Glycine['TRUE'], Field_Glycine['HGBR']-Field_Glycine['TRUE'], color = 'gold', label = 'HGBR', marker='^')
plt.scatter(Field_Glycine['TRUE'], Field_Glycine['DT']-Field_Glycine['TRUE'], color = 'darkgreen', label = 'DT', marker='^')
plt.scatter(Field_Glycine['TRUE'], Field_Glycine['KNN']-Field_Glycine['TRUE'], color = 'dodgerblue', label = 'KNN', marker='^')
plt.scatter(Field_Glycine['TRUE'], Field_Glycine['SVR']-Field_Glycine['TRUE'], color = 'darkorchid', label = 'SVR', marker='^')
plt.scatter(Field_Glycine['TRUE'], Field_Glycine['MLP']-Field_Glycine['TRUE'], color = 'hotpink', label = 'MLP', marker='^')
plt.scatter(Field_Glycine['TRUE'], Field_Glycine['MLR']-Field_Glycine['TRUE'], color = 'dimgray', label = 'MLR', marker='^')


plt.title('Spiked Ocean Models')
#plt.ylabel('Predicted - True Concentration (mM)')
plt.xlabel('True Concentration (mM)')

#plt.legend(frameon = True, loc="upper right", ncol = 2)
plt.ylim(-50,50)
plt.axhline(0, color = 'grey', linewidth = 0.5)
plt.axhline(Field_Glycine['TRUE'].max()/10, color = 'k', linewidth = 0.6, linestyle = ':')
plt.axhline(-Field_Glycine['TRUE'].max()/10, color = 'k', linewidth = 0.6, linestyle = ':')

# %% [markdown]
# # Butyric Acid

# %%
plt.scatter(Lab_Butyric_Acid['TRUE'], Lab_Butyric_Acid['GBR']-Lab_Butyric_Acid['TRUE'], color = 'crimson', label = 'GBR', marker='o')
plt.scatter(Lab_Butyric_Acid['TRUE'], Lab_Butyric_Acid['RF']-Lab_Butyric_Acid['TRUE'], color = 'darkorange', label = 'RF', marker='o')
plt.scatter(Lab_Butyric_Acid['TRUE'], Lab_Butyric_Acid['HGBR']-Lab_Butyric_Acid['TRUE'], color = 'gold', label = 'HGBR', marker='o')
plt.scatter(Lab_Butyric_Acid['TRUE'], Lab_Butyric_Acid['DT']-Lab_Butyric_Acid['TRUE'], color = 'darkgreen', label = 'DT', marker='o')
plt.scatter(Lab_Butyric_Acid['TRUE'], Lab_Butyric_Acid['KNN']-Lab_Butyric_Acid['TRUE'], color = 'dodgerblue', label = 'KNN', marker='o')
plt.scatter(Lab_Butyric_Acid['TRUE'], Lab_Butyric_Acid['SVR']-Lab_Butyric_Acid['TRUE'], color = 'darkorchid', label = 'SVR', marker='o')
plt.scatter(Lab_Butyric_Acid['TRUE'], Lab_Butyric_Acid['MLP']-Lab_Butyric_Acid['TRUE'], color = 'hotpink', label = 'MLP', marker='o')
plt.scatter(Lab_Butyric_Acid['TRUE'], Lab_Butyric_Acid['MLR']-Lab_Butyric_Acid['TRUE'], color = 'dimgray', label = 'MLR', marker='o')


plt.title('Spiked Lab Models')
plt.ylabel('Predicted - True Concentration (mM)')
plt.xlabel('True Concentration (mM)')

plt.legend(frameon = True, loc="upper right", ncol = 2)
plt.ylim(-50,50)
plt.axhline(0, color = 'grey', linewidth = 0.5)
plt.axhline((Field_Butyric_Acid['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')
plt.axhline(-(Field_Butyric_Acid['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')

# %%
plt.scatter(Field_Butyric_Acid['TRUE'], Field_Butyric_Acid['GBR']-Field_Butyric_Acid['TRUE'], color = 'crimson', label = 'GBR', marker='^')
plt.scatter(Field_Butyric_Acid['TRUE'], Field_Butyric_Acid['RF']-Field_Butyric_Acid['TRUE'], color = 'darkorange', label = 'RF', marker='^')
plt.scatter(Field_Butyric_Acid['TRUE'], Field_Butyric_Acid['HGBR']-Field_Butyric_Acid['TRUE'], color = 'gold', label = 'HGBR', marker='^')
plt.scatter(Field_Butyric_Acid['TRUE'], Field_Butyric_Acid['DT']-Field_Butyric_Acid['TRUE'], color = 'darkgreen', label = 'DT', marker='^')
plt.scatter(Field_Butyric_Acid['TRUE'], Field_Butyric_Acid['KNN']-Field_Butyric_Acid['TRUE'], color = 'dodgerblue', label = 'KNN', marker='^')
plt.scatter(Field_Butyric_Acid['TRUE'], Field_Butyric_Acid['SVR']-Field_Butyric_Acid['TRUE'], color = 'darkorchid', label = 'SVR', marker='^')
plt.scatter(Field_Butyric_Acid['TRUE'], Field_Butyric_Acid['MLP']-Field_Butyric_Acid['TRUE'], color = 'hotpink', label = 'MLP', marker='^')
plt.scatter(Field_Butyric_Acid['TRUE'], Field_Butyric_Acid['MLR']-Field_Butyric_Acid['TRUE'], color = 'dimgray', label = 'MLR', marker='^')


plt.title('Spiked Ocean Models')
plt.ylabel('Predicted - True Concentration (mM)')
plt.xlabel('True Concentration (mM)')

plt.legend(frameon = True, loc="upper right", ncol = 2)
plt.ylim(-50,50)
plt.axhline(0, color = 'grey', linewidth = 0.5)
plt.axhline((Field_Butyric_Acid['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')
plt.axhline(-(Field_Butyric_Acid['TRUE'].max()/10)*2, color = 'k', linewidth = 0.6, linestyle = ':')

# %%
df = pd.DataFrame([['GBR',3.9803  ,10.0311 , 7.7605], ['RF', 2.4878, 7.8313, 7.0849], ['HGBR', 4.4296, 2.3265, 2.3758], ['DT', 1.9368 , 9.7189 , 9.6685], ['KNN', 13.9546, 10.3931, 11.96], ['SVR', 27.0491, 23.8804, 25.1792], ['MLP', 24.3857, 24.2092, 25.3321], ['MLR', 20.7719, 21.0909,23.2032]],columns=['ML', 'Glycine Error', 'Butyric Acid Error', 'Glucose Error'])

# %%
df.plot(ylim=(0,40),x='ML', kind='bar', stacked=False, title='Testing Error of Spiked Lab Models', color = {'Glycine Error': 'black', 'Butyric Acid Error': 'gray', 'Glucose Error': 'silver'})
plt.legend(frameon = False, loc='best')
plt.ylabel('RMSE (mM)')
# Out:
# Text(0, 0.5, 'RMSE (mM)')

# %%
df = pd.DataFrame([['GBR',13.3496 ,12.8839 , 0.2431], ['RF', 21.7134, 13.7873, 15.8331], ['HGBR', 13.3528 , 12.1239, 14.3884], ['DT', 16.0507, 13.8104, 18.4302], ['KNN', 11.6552, 13.9847, 23.1764], ['SVR', 18.8139, 26.2249, 34.5388], ['MLP', 17.0440, 25.3864, 25.3321], ['MLR', 13.5610 , 21.0909, 30.2604]],columns=['ML', 'Glycine Error', 'Butyric Acid Error', 'Glucose Error'])

# %%
df.plot(ylim=(0,40),x='ML', kind='bar', stacked=False, title='Testing Error of Spiked Ocean Models', color = {'Glycine Error': 'black', 'Butyric Acid Error': 'gray', 'Glucose Error': 'silver'})
#plt.legend(frameon = False, loc='best')
#plt.ylabel('RMSE (M)')
#plt.ylim(0, 0.1)
# Out:
# <Axes: title={'center': 'Testing Error of Spiked Ocean Models'}, xlabel='ML'>

# %%
df = pd.DataFrame([['GBR',3,5,4,9,7,7 ],['RF',0,5,0,8,2,6], ['HGBR',0,2,4,9,6,7], ['DT',0,6,5,7,2,5], ['KNN',1,4,6,5,1,7], ['SVR',0,7,7,9,2,8], ['MLP',0,0,5,6,1,2], ['MLR',0,0,5,7,4,6]],columns=['ML','SL Glycine', 'SM Glycine', 'SL Butyric Acid', 'SM Butyric Acid', 'SL Glucose', 'SM Glucose'])

# %%
df
# Out:
#      ML  SL Glycine  SM Glycine  SL Butyric Acid  SM Butyric Acid  SL Glucose  \
# 0   GBR           3           5                4                9           7
# 1    RF           0           5                0                8           2
# 2  HGBR           0           2                4                9           6
# 3    DT           0           6                5                7           2
# 4   KNN           1           4                6                5           1
# 5   SVR           0           7                7                9           2
# 6   MLP           0           0                5                6           1
# 7   MLR           0           0                5                7           4
#
#    SM Glucose
# 0           7
# 1           6
# 2           7
# 3           5
# 4           7
# 5           8
# 6           2
# 7           6

# %%
df.plot(legend = False, x='ML', kind='bar', stacked=False, title='Number of Predictions within 20% mM', color = {'SL Glycine': 'black', 'SM Glycine': 'Grey', 'SL Butyric Acid': 'brown', 'SM Butyric Acid': 'lightcoral','SL Glucose': 'blue', 'SM Glucose': 'cornflowerblue'})
plt.legend(ncol=3, frameon = False, fontsize=9)
#plt.ylabel('RMSE (M)')
plt.ylim(0, 11)
plt.savefig(r'C:\Users\north.154\OneDrive - The Ohio State University\Desktop\Current Work\Papers\Ocean ML Paper\Model_Results\No_Pred.png', dpi=300)

# %%
df
# Out:
#      ML  SL Glycine  SM Glycine  SL Butyric Acid  SM Butyric Acid  SL Glucose  \
# 0   GBR           3           5                4                7           7
# 1    RF           0           5                0                8           2
# 2  HGBR           0           2                4                9           6
# 3    DT           0           6                5                7           2
# 4   KNN           1           4                6                5           1
# 5   SVR           0           7                7                9           2
# 6   MLP           0           0                5                6           1
# 7   MLR           0           0                5                7           4
#
#    SM Glucose
# 0           9
# 1           6
# 2           7
# 3           5
# 4           7
# 5           8
# 6           2
# 7           6
